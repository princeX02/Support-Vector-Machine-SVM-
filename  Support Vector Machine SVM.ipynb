# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
data=pd.read_csv("Placement.csv")

# %%
data.head(3)
# Out:
#    Student_ID  CGPA   IQ  Placement
# 0           1   6.8  123          1
# 1           2   5.9  106          0
# 2           3   5.3  121          0

# %%
data.drop(columns="Student_ID",inplace=True)

# %%
data.head(3)
# Out:
#    CGPA   IQ  Placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0

# %%
data.isnull().sum()
# Out:
# CGPA         0
# IQ           0
# Placement    0
# dtype: int64

# %%
sns.scatterplot(x="CGPA",y="IQ",hue="Placement",data=data)
plt.show()

# %%
x=data.iloc[:,:-1]
y=data["Placement"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
sv=SVC(kernel="linear")

# %%
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 95.0

# %%
sv.score(x_train,y_train)*100
# Out:
# 91.25

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# /Users/princechaudhary/myenv/lib/python3.13/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
